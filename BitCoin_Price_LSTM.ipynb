# %% [markdown]
# ##Importing Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20,10

# %% [markdown]
# ##Reading File

# %%
df = pd.read_csv('coin_Bitcoin.csv')
df.head()
# Out:
#    SNo     Name Symbol  ...       Close  Volume     Marketcap
# 0    1  Bitcoin    BTC  ...  144.539993     0.0  1.603769e+09
# 1    2  Bitcoin    BTC  ...  139.000000     0.0  1.542813e+09
# 2    3  Bitcoin    BTC  ...  116.989998     0.0  1.298955e+09
# 3    4  Bitcoin    BTC  ...  105.209999     0.0  1.168517e+09
# 4    5  Bitcoin    BTC  ...   97.750000     0.0  1.085995e+09
#
# [5 rows x 10 columns]

# %% [markdown]
# ##Diplaying Price History

# %%
df['Date'] = pd.to_datetime(df.Date,format='%Y-%m-%d')
df.index = df['Date']
plt.figure(figsize=(16,8))
plt.plot(df['Close'], label='Close Price history')

# %% [markdown]
# ## Preprocessing and Building Model

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM

data = df.sort_index(ascending=True, axis=0)
final_data = pd.DataFrame(index=range(0,len(df)),columns=['Date', 'Close'])
for i in range(0,len(data)):
    final_data['Date'][i] = data['Date'][i]
    final_data['Close'][i] = data['Close'][i]

final_data.index = final_data.Date
final_data.drop('Date', axis=1, inplace=True)

dataset = final_data.values

train = dataset[0:987,:]
valid = dataset[987:,:]

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

x_train, y_train = [], []
for i in range(60,len(train)):
    x_train.append(scaled_data[i-60:i,0])
    y_train.append(scaled_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(LSTM(units=50))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x_train, y_train, epochs=1, batch_size=1, verbose=2)

inputs = final_data[len(final_data) - len(valid) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)

X_test = []
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)

X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
closing_price = model.predict(X_test)
closing_price = scaler.inverse_transform(closing_price)
# Out:
# 927/927 - 25s - loss: 8.7474e-06

# %% [markdown]
# ##Calculating Root Mean Square Error

# %%
rms=np.sqrt(np.mean(np.power((valid-closing_price),2)))
rms
# Out:
# 2582.534843437961

# %% [markdown]
# ##Displaying Graph of Final Results

# %%
#for plotting
training_data = final_data[:987]
validation_data = final_data[987:]
validation_data['Predictions'] = closing_price
plt.plot(training_data['Close'])
plt.plot(validation_data[['Close','Predictions']])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
